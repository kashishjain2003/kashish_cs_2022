# %%
import pandas as pd

# %% [raw]
# Data Analysis
# 1. Description
# 2. Diagnosis
# 3. Prediction
# 4. Actions/Prescription

# %%
# The column names
cols = ['user_id','movie_id','rating','ts']

# %%
# Read the file
df=pd.read_csv('u.data', sep='\t', names=cols)

# %%
item_cols=['movie_id','title']+[str(i) for i in range(22)]

# %%
# Read the other file
df1=pd.read_csv('u.item',sep='|',names=item_cols, encoding ="ISO-8859-1")[['movie_id','title']]

# %%
df1.head()
# Out:
#    movie_id              title
# 0         1   Toy Story (1995)
# 1         2   GoldenEye (1995)
# 2         3  Four Rooms (1995)
# 3         4  Get Shorty (1995)
# 4         5     Copycat (1995)

# %% [markdown]
# Exploratory Data Ananlysis

# %%
df1.shape
# Out:
# (1682, 2)

# %%
df.head()
# Out:
#    user_id  movie_id  rating         ts
# 0        0        50       5  881250949
# 1        0       172       5  881250949
# 2        0       133       1  881250949
# 3      196       242       3  881250949
# 4      186       302       3  891717742

# %%
df.sample(3)
# Out:
#        user_id  movie_id  rating         ts
# 73422      417       713       2  879646052
# 80007      889       523       4  880178078
# 821         44       443       5  878348289

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100003 entries, 0 to 100002
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user_id   100003 non-null  int64
#  1   movie_id  100003 non-null  int64
#  2   rating    100003 non-null  int64
#  3   ts        100003 non-null  int64
# dtypes: int64(4)
# memory usage: 3.1 MB

# %%
df.describe(include='all')
# Out:
#              user_id       movie_id         rating            ts
# count  100003.000000  100003.000000  100003.000000  1.000030e+05
# mean      462.470876     425.520914       3.529864  8.835288e+08
# std       266.622454     330.797791       1.125704  5.343791e+06
# min         0.000000       1.000000       1.000000  8.747247e+08
# 25%       254.000000     175.000000       3.000000  8.794487e+08
# 50%       447.000000     322.000000       4.000000  8.828269e+08
# 75%       682.000000     631.000000       4.000000  8.882600e+08
# max       943.000000    1682.000000       5.000000  8.932866e+08

# %% [raw]
# Try to find Different Data
# 1. Strings with Categorical Info
# 2. Strings with Random Stuff
# 3. Numbers with Quantified Info
# 4. Numbers with Categorical Info
# 5. Random Numbers or ID sort of data

# %%
df.columns
# Out:
# Index(['user_id', 'movie_id', 'rating', 'ts'], dtype='object')

# %%
df['rating'].unique()
# Out:
# array([5, 1, 3, 2, 4], dtype=int64)

# %%
df['rating'].nunique()
# Out:
# 5

# %%
df['user_id'].nunique()
# Out:
# 944

# %%
df['movie_id'].nunique()
# Out:
# 1682

# %%
# Merging DataFrames

# %%
movie=pd.merge(df,df1,on='movie_id')
movie.head()
# Out:
#    user_id  movie_id  rating         ts             title
# 0        0        50       5  881250949  Star Wars (1977)
# 1      290        50       5  880473582  Star Wars (1977)
# 2       79        50       4  891271545  Star Wars (1977)
# 3        2        50       5  888552084  Star Wars (1977)
# 4        8        50       5  879362124  Star Wars (1977)

# %%
movie.head()
# Out:
#    user_id  movie_id  rating         ts             title
# 0        0        50       5  881250949  Star Wars (1977)
# 1      290        50       5  880473582  Star Wars (1977)
# 2       79        50       4  891271545  Star Wars (1977)
# 3        2        50       5  888552084  Star Wars (1977)
# 4        8        50       5  879362124  Star Wars (1977)

# %%
#Find the number of rating for each movie
movie.groupby('title').count()
# Out:
#                                        user_id  movie_id  rating   ts
# title
# 'Til There Was You (1997)                    9         9       9    9
# 1-900 (1994)                                 5         5       5    5
# 101 Dalmatians (1996)                      109       109     109  109
# 12 Angry Men (1957)                        125       125     125  125
# 187 (1997)                                  41        41      41   41
# ...                                        ...       ...     ...  ...
# Young Guns II (1990)                        44        44      44   44
# Young Poisoner's Handbook, The (1995)       41        41      41   41
# Zeus and Roxanne (1997)                      6         6       6    6
# unknown                                      9         9       9    9
# Á köldum klaka (Cold Fever) (1994)           1         1       1    1
#
# [1664 rows x 4 columns]

# %%
movie['title'].value_counts().head(10)
# Out:
# Star Wars (1977)                 584
# Contact (1997)                   509
# Fargo (1996)                     508
# Return of the Jedi (1983)        507
# Liar Liar (1997)                 485
# English Patient, The (1996)      481
# Scream (1996)                    478
# Toy Story (1995)                 452
# Air Force One (1997)             431
# Independence Day (ID4) (1996)    429
# Name: title, dtype: int64

# %%
#Find the average rating for each movie
movie.groupby('title')['rating'].mean().sort_values(ascending=False).head(10)
# Out:
# title
# They Made Me a Criminal (1939)                       5.0
# Marlene Dietrich: Shadow and Light (1996)            5.0
# Saint of Fort Washington, The (1993)                 5.0
# Someone Else's America (1995)                        5.0
# Star Kid (1997)                                      5.0
# Great Day in Harlem, A (1994)                        5.0
# Aiqing wansui (1994)                                 5.0
# Santa with Muscles (1996)                            5.0
# Prefontaine (1997)                                   5.0
# Entertaining Angels: The Dorothy Day Story (1996)    5.0
# Name: rating, dtype: float64

# %%
ratings=pd.DataFrame(movie.groupby('title')\
                     ['rating'].mean().sort_values(ascending=False))

# %%
ratings['count']=movie['title'].value_counts()

# %%
ratings.head(20)
# Out:
#                                                       rating    count
# title
# They Made Me a Criminal (1939)                      5.000000  0.00001
# Marlene Dietrich: Shadow and Light (1996)           5.000000  0.00001
# Saint of Fort Washington, The (1993)                5.000000  0.00002
# Someone Else's America (1995)                       5.000000  0.00001
# Star Kid (1997)                                     5.000000  0.00003
# Great Day in Harlem, A (1994)                       5.000000  0.00001
# Aiqing wansui (1994)                                5.000000  0.00001
# Santa with Muscles (1996)                           5.000000  0.00002
# Prefontaine (1997)                                  5.000000  0.00003
# Entertaining Angels: The Dorothy Day Story (1996)   5.000000  0.00001
# Pather Panchali (1955)                              4.625000  0.00008
# Some Mother's Son (1996)                            4.500000  0.00002
# Maya Lin: A Strong Clear Vision (1994)              4.500000  0.00004
# Anna (1996)                                         4.500000  0.00002
# Everest (1998)                                      4.500000  0.00002
# Close Shave, A (1995)                               4.491071  0.00112
# Schindler's List (1993)                             4.466443  0.00298
# Wrong Trousers, The (1993)                          4.466102  0.00118
# Casablanca (1942)                                   4.456790  0.00243
# Wallace & Gromit: The Best of Aardman Animation...  4.447761  0.00067

# %%
ratings.sort_values(by='count',ascending=False).head(20)
# Out:
#                                     rating    count
# title
# Star Wars (1977)                  4.359589  0.00584
# Contact (1997)                    3.803536  0.00509
# Fargo (1996)                      4.155512  0.00508
# Return of the Jedi (1983)         4.007890  0.00507
# Liar Liar (1997)                  3.156701  0.00485
# English Patient, The (1996)       3.656965  0.00481
# Scream (1996)                     3.441423  0.00478
# Toy Story (1995)                  3.878319  0.00452
# Air Force One (1997)              3.631090  0.00431
# Independence Day (ID4) (1996)     3.438228  0.00429
# Raiders of the Lost Ark (1981)    4.252381  0.00420
# Godfather, The (1972)             4.283293  0.00413
# Pulp Fiction (1994)               4.060914  0.00394
# Twelve Monkeys (1995)             3.798469  0.00392
# Silence of the Lambs, The (1991)  4.289744  0.00390
# Jerry Maguire (1996)              3.710938  0.00384
# Chasing Amy (1997)                3.839050  0.00379
# Rock, The (1996)                  3.693122  0.00378
# Empire Strikes Back, The (1980)   4.206522  0.00368
# Star Trek: First Contact (1996)   3.660274  0.00365

# %%
movie_pivot=movie.pivot_table(index='user_id',columns='title',values='rating')
movie_pivot.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# 0                                        NaN                           NaN
# 1                                        3.0                           4.0
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
#
# title    3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# user_id
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                1.0                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
#
# title    ...  Yankee Zulu (1994)  Year of the Horse (1997)  \
# user_id  ...
# 0        ...                 NaN                       NaN
# 1        ...                 NaN                       NaN
# 2        ...                 NaN                       NaN
# 3        ...                 NaN                       NaN
# 4        ...                 NaN                       NaN
#
# title    You So Crazy (1994)  Young Frankenstein (1974)  Young Guns (1988)  \
# user_id
# 0                        NaN                        NaN                NaN
# 1                        NaN                        5.0                3.0
# 2                        NaN                        NaN                NaN
# 3                        NaN                        NaN                NaN
# 4                        NaN                        NaN                NaN
#
# title    Young Guns II (1990)  Young Poisoner's Handbook, The (1995)  \
# user_id
# 0                         NaN                                    NaN
# 1                         NaN                                    NaN
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
#
# title    Zeus and Roxanne (1997)  unknown  Á köldum klaka (Cold Fever) (1994)
# user_id
# 0                            NaN      NaN                                 NaN
# 1                            NaN      4.0                                 NaN
# 2                            NaN      NaN                                 NaN
# 3                            NaN      NaN                                 NaN
# 4                            NaN      NaN                                 NaN
#
# [5 rows x 1664 columns]

# %% [markdown]
# Correlation

# %%
movie_selected='Star Wars (1977)'

# %%
ms_rates=movie_pivot[movie_selected]
ms_rates.head()
# Out:
# user_id
# 0    5.0
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# Name: Star Wars (1977), dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
corrs=movie_pivot.corrwith(ms_rates).sort_values(ascending=False)
corrs.head(10)
# Out:
# title
# Hollow Reed (1996)                                                                   1.0
# Stripes (1981)                                                                       1.0
# Star Wars (1977)                                                                     1.0
# Man of the Year (1995)                                                               1.0
# Beans of Egypt, Maine, The (1994)                                                    1.0
# Safe Passage (1994)                                                                  1.0
# Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)    1.0
# Outlaw, The (1943)                                                                   1.0
# Line King: Al Hirschfeld, The (1996)                                                 1.0
# Hurricane Streets (1998)                                                             1.0
# dtype: float64

# %%
corrs.sort_values(ascending=False).head(10)
# Out:
# title
# Hollow Reed (1996)              1.0
# Star Wars (1977)                1.0
# Man of the Year (1995)          1.0
# Stripes (1981)                  1.0
# Good Man in Africa, A (1994)    1.0
# Mondo (1996)                    1.0
# Ed's Next Move (1996)           1.0
# Twisted (1996)                  1.0
# Full Speed (1996)               1.0
# Golden Earrings (1947)          1.0
# dtype: float64

# %%
corrs_df=pd.DataFrame(corrs,columns=['Correlation'])
corrs_df.head()
# Out:
#                                    Correlation
# title
# Hollow Reed (1996)                         1.0
# Stripes (1981)                             1.0
# Star Wars (1977)                           1.0
# Man of the Year (1995)                     1.0
# Beans of Egypt, Maine, The (1994)          1.0

# %%
corrs_df['rating']=ratings['rating']
corrs_df['count']=ratings['count']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 corrs_df['rating']=ratings['rating']
#       2 corrs_df['count']=ratings['count']
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py:389, in RangeIndex.get_loc(self, key, method, tolerance)
#     387             raise KeyError(key) from err
#     388     self._check_indexing_error(key)
# --> 389     raise KeyError(key)
#     390 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'rating'

# %%
corrs_df[corrs_df['count']>50].sort_values(by='correlation',ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 corrs_df[corrs_df['count']>50].sort_values(by='correlation',ascending=False).head(10)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'count'
